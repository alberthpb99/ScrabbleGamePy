# %% [markdown]
# ### Acceso a Google Drive
# Conectamos el entorno de Colab a Google Drive para cargar los archivos necesarios.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/FroGames/Python A-Z/Proyecto_Final"
# Out:
# /content/drive/MyDrive/Colab Notebooks/FroGames/Python A-Z/Proyecto_Final

# %% [markdown]
# ### Importación de módulos
#
# Importamos el módulo principal y las clases necesarias para ejecutar el juego.

# %%
import ApylabradosModule
from ApylabradosModule import Pawns, Word, Dictionary, FrequencyTable, Board

# %% [markdown]
# ### Ejecución del juego

# %%
ApylabradosModule.startGame()

while not ApylabradosModule.end and ApylabradosModule.bag_of_pawns.getTotalPawns()>0:
    ApylabradosModule.show_options()

if ApylabradosModule.bag_of_pawns.getTotalPawns() <= 0:
    print('Te has quedado sin fichas!')
    print('El juego ha terminado.')

print(f'¡¡Has conseguido {Board.score} puntos en esta partida!!')
# Out:
# ¡Bienvenido a Apylabrados!
#
# ¡Pon a prueba tu ingenio, tu inglés, tus palabras y tu estrategia!
# Combina letras, forma palabras y conquista el tablero como un verdadero maestro.
#
# -----------------------------------------------------------------------------------------------------
# Instrucciones del juego:
# 	1) Las palabras deben ser en inglés
# 	2) La primera palabra que introduzcas debe pasar por el centro del tablero (posición = [7,7])
# 	3) Las siguientes palabras deben utilizar al menos una ficha del tablero
# 	4) Las posibles direcciones son:
# 		V : Vertical
# 		H : Horizontal
# ------------------------------------------------------------------------------------------------------
# Que te gustaría hacer?
#
# Para introducir una palabra, introduce ENTERWORD
# Para ver los puntos de cada ficha, introduce PAWNSPOINTS
# Para ver los multiplicadores, introduce HELPLEGEND
# Para obtener ayuda y ver las posibles palabras a armar con tus fichas, introduce HELPWORD
# ...
